# %% [markdown]
# # Написать приложение или функцию, которые собирают основные новости с сайта на выбор lenta.ru, yandex-новости. Для парсинга использовать XPath.

# %%
from pprint import pprint
from lxml import html
import requests

# %%
url = 'https://yandex.ru/news/'

headers = {
    'User-Agent':	'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36',
}
params = {
}

response = requests.get(url, headers=headers, params=params)
response.url
# Out:
# 'https://yandex.ru/news/'

# %%
dom = html.fromstring(response.text)
new = dom.xpath(".//div[@class ='mg-card-footer__left']")

# %%
news_dict = {}

for news in new:
  if(len(news.xpath(".//../../h2/a/text()"))!=0):
      news_name = news.xpath(".//../../h2/a/text()")[0]
      news_link = news.xpath(".//../../h2/a/@href")[0]
      news_date = news.xpath(".//span[@class='mg-card-source__time']/text()")[0]
      news_source = news.xpath(".//../../div/span/a/text()")[0]
  elif(len(news.xpath(".//../../div/div/h2/a/text()"))!=0):
      news_name = news.xpath(".//../../div[@class='mg-card__text-content']/div/h2/a/text()")[0]
      news_link = news.xpath(".//../../h2/a/@href")
      news_date = news.xpath(".//span[@class='mg-card-source__time']/text()")[0]
      news_source = news.xpath(".//../../div/span/a/text()")[0]
  else: 
      news_name = news.xpath(".//../../div/div/div/h2/a/text()")[0]
      news_link = news.xpath(".//../../h2/a/@href")
      news_date = news.xpath(".//span[@class='mg-card-source__time']/text()")[0]
      news_source = news.xpath(".//../../div/span/a/text()")[0]
  news_dict[news_name] = {
    'link': image,
    'date': news_date,          
    'source': news_source,
    }

# %%
news_dict
# Out:
# {'ВГА Энергодара: Подачу энергии с\xa0ЗАЭС на\xa0подконтрольные Киеву территории приостановили': {'link': 'https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg',
#   'date': '22:37',
#   'source': 'РБК'},
#  'Около 70 тысяч жителей Праги вышли на\xa0митинг с\xa0требованием дешевого газа': {'link': 'https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg',
#   'date': '22:32',
#   'source': 'РИА Новости'},
#  'Французский журналист Ленгле: Россия зарабатывает на\xa0нефти и газе 3700 евро в\xa0секунду': {'link': 'https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg',
#   'date': '22:37',
#   'source': 'Lenta.ru'},
#  'Кадыров заявил, что засиделся на\xa0посту главы Чечни и заслужил бессрочный отпуск': {'link': 'https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg',
#   'date': '21:59',
#   'source': 'РИА Новости'},
# ...
